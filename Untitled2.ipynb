# %%
ints = [1,3,5,9,15]
print(ints[0])
print(ints[-1])
print(ints[::2])
print(ints[::-1])
# Out:
# 1
# 15
# [1, 5, 15]
# [15, 9, 5, 3, 1]

# %%
def series(end, step, start=0):
    return list(range(start, end, step))
